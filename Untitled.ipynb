# %%
import pandas as pd

# %%
a = pd.read_excel("evasão.xlsl")
a
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/pandas/io/excel.py in __init__(self, io, **kwds)
#     260         try:
# --> 261             import xlrd
#     262         except ImportError:
#
# ImportError: No module named 'xlrd'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-4948d7352bfd> in <module>()
# ----> 1 a = pd.read_excel("evasão.xlsl")
#       2 a
#
# /usr/local/lib/python3.5/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# ...

# %%
a = pd.read_csv("/home/wesley/Downloads/deleted_Relat&#243;rio_final_evas&#227;o-na-UNIPAMPA_out20111.xlsx - Table 17.csv")

# %%
a

a.drop([0,1])
lastCampus='Alegrete'
for i in range (0, a.Campus.size):
    if(pd.isnull(a.Campus.iloc[i])):
        a.Campus.iloc[i]=lastCampus
    else:
        lastCampus=a.Campus.iloc[i]
    if(pd.isnull(a.NOME_CURSO.iloc[i])):
        a.NOME_CURSO.iloc[i]=lastCurse
    else:
        lastCurse=a.NOME_CURSO.iloc[i]
        

lista_de_drop=[]
if(a.columns.contains('Unnamed: 1')):
    lista_de_drop.append('Unnamed: 1')
if(a.columns.contains('Total de estudantes')):
    lista_de_drop.append('Total de estudantes')
if(a.columns.contains('Nº por Campus')):
    lista_de_drop.append('Nº por Campus')
if(not lista_de_drop==[]):
    a.drop(lista_de_drop,axis=1,inplace=True)
a  = a[:-5]


a
# Out:
# /usr/local/lib/python3.5/dist-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#                                            NOME_CURSO  \
# 0                      CURSO DE CIENCIA DA COMPUTACAO
# 1                        CURSO DE ENGENHARIA AGRÍCOLA
# 2                        CURSO DE ENGENHARIA AGRÍCOLA
# 3                           CURSO DE ENGENHARIA CIVIL
# 4                           CURSO DE ENGENHARIA CIVIL
# 5                        CURSO DE ENGENHARIA ELETRICA
# 6                        CURSO DE ENGENHARIA MECANICA
# 7                     CURSO DE ENGENHARIA DE SOFTWARE
# 8                     CURSO DE ENGENHARIA DE SOFTWARE
# 9                   CURSO DE ENGENHARIA DE COMPUTACAO
# ...
